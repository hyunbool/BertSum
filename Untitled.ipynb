# %%
import os
import json

# %%
fiels = os.listdir("./raw_data")

# %%
a = [f for f in fiels if ".story" not in f]

# %%
a
# Out:
# []

# %%
json_data = os.listdir("./json_data")

# %%
with open("./json_data/" + json_data[0], "r") as st_json:

    st_python = [json.load(st_json)]

# %%
st_python[0][0]['src']
# Out:
# [['by'],
#  ['hugo', 'gye'],
#  ['published', ':'],
#  ['02:25', 'est', ',', '26', 'august', '2013'],
#  ['|'],
#  ['updated', ':'],
#  ['03:41', 'est', ',', '27', 'august', '2013'],
#  ['cigarettes',
#   'could',
#   'be',
#   'banned',
#   'from',
#   'being',
#   'sold',
#   'in',
#   'packets',
#   'of',
#   '10',
#   'in',
#   'an',
#   'eu',
#   'bid',
#   'to',
#   'prevent',
#   'children',
#   'from',
#   'starting',
#   'to',
#   'smoke',
#   '.'],
#  ['the',
#   'planned',
#   'curbs',
#   ',',
#   'which',
#   'would',
#   'also',
#   'hit',
#   'menthol',
#   'and',
#   "'",
#   'slim',
#   "'",
#   'cigarettes',
#   ',',
#   'could',
#   'outlaw',
#   'the',
#   'sale',
#   'of',
#   'more',
#   'than',
#   'half',
#   'of',
#   'all',
#   'tobacco',
#   'currently',
#   'sold',
#   'in',
#   'britain',
#   '.'],
#  ['tobacco',
#   'giants',
#   'have',
#   'lashed',
#   'out',
#   'against',
#   'the',
#   'proposed',
#   'legislation',
#   ',',
#   'claiming',
# ...
